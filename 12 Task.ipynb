# %%
from tqdm import tqdm
import scipy.stats as scst
import scipy as sc
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import scipy.special as sp

# %% [markdown]
# ![111.png](data:image/png;base64,...)

# %% [markdown]
# # 1)

# %%
from statsmodels.distributions.empirical_distribution import ECDF
N = [10, 50, 100]
def plot(X, dist_name, n):
    plt.figure()
    ecdf = ECDF(X)
    x = np.linspace(min(X), max(X), 1000)
    y = ecdf(x)
    plt.plot(x, y, label='ecdf', color = 'blue')
    if dist_name == 'N(0, 1)':
        cdf = sts.norm.cdf(x, loc = 0, scale = 1)
        res = sts.kstwobign.ppf(0.95)
        
    elif dist_name == 'R[0; 1]':
        cdf = scst.uniform.cdf(x, loc = 0, scale = 1)
        res = scst.kstwobign.ppf(0.95)
        
    elif dist_name == 'Binom(3, 1/2)':
        cdf = scst.binom.cdf(x, n = 3, p = 0.5)
        res = scst.kstwobign.ppf(0.95)
        
    elif dist_name == 'Binom(10, 1/2)':
        cdf = scst.binom.cdf(x, n = 10, p = 0.5)
        res = scst.kstwobign.ppf(0.95)
        
    plt.plot(x, cdf, label='distr func', color = 'purple')
    plt.fill_between(x, cdf - res/np.sqrt(n), cdf + res/np.sqrt(n), color = 'green', alpha = 0.2, label = "kolmogorov")
    eps = np.sqrt((1/(2*n)) * np.log(2/0.05))
    plt.fill_between(x, cdf - eps, cdf + eps, color = 'blue', alpha = 0.2, label = "DKW ineq")

    plt.title(dist_name + ', n = ' + str(n))
    plt.legend()
    plt.show()
for n in N:
    X = scst.norm.rvs(size = n)
    plot(X, 'N(0, 1)', n)
    
    X = scst.uniform(loc = 0, scale = 1).rvs(size = n)
    plot(X, 'R[0; 1]', n)
    
    X = scst.binom(n = 3, p = 0.5).rvs(size = n)
    plot(X, 'Binom(3, 1/2)', n)
    
    X = scst.binom(n = 10, p = 0.5).rvs(size = n)
    plot(X, 'Binom(10, 1/2)', n)

# %% [markdown]
# ![222.png](data:image/png;base64,...)

# %% [markdown]
# # 2)

# %%
from statsmodels.distributions.empirical_distribution import ECDF
def pval_bin(n:int, k:int):
    m = 200
    result = []
    for j in range (m):
        Y = sts.binom.rvs(n = k, p = 1/2, size=n)
        #Sample = (Y - np.mean(Y))/np.std(Y)
        Sample = (Y - k*1/2)/np.sqrt(k/4)
        sample_val = scst.kstest(Sample, 'norm')
        result = np.append(result, sample_val.pvalue)
    result = np.sort(result)
    y_vals = [(i+1)/m for i in range(m)]
    ax.plot(result, y_vals, lw = 2, label = f"m = {k}")

def pval_ih(n:int, k:int):
    m = 200
    result = []
    for j in range (m):
        Y = np.sum(np.random.uniform(size=(m, n)), axis=0)
        # Sample = (Y - np.mean(Y))/np.std(Y)
        Sample = (Y - m*1/2)/np.sqrt(m/12)
        sample_val = scst.kstest(Sample, 'norm')
        result = np.append(result,sample_val.pvalue)
    result = np.sort(result)
    y_vals = [(i+1)/m for i in range(m)]
    ax.plot(result, y_vals, lw = 2, label = f"m = {k}")

N = [50, 100, 500]
M = [1,2,5,20]
def task(Y, n):
    pvalue_test = 0.05
    X = (Y - np.mean(Y))/np.std(Y)
    x = np.linspace(min(Y), max(Y), 1000)
    res = scst.kstwobign.ppf(0.95)
    res = scst.kstest(X, 'norm').pvalue
    h_accepted = res > pvalue_test
    print(f"Hypothesis acceptance for n = {n}: {h_accepted}. Pvalue: {res}")

print("N(0,1)")
for n in N:
    Y = sts.norm.rvs(loc = -3, scale = np.sqrt(8), size = n)
    task(Y, n)
print("")
for n in N:
    fig, ax = plt.subplots()
    plt.title(f"pvalue for Binom with n = {n}")
    for m in M:
        print(f"Bin({m}, 1/2)")
        Y = sts.binom.rvs(n = m, p = 1/2, size = n)
        task(Y, n)
        pval_bin(n, m)
    ax.legend()
    print("")

for n in N:
    fig, ax = plt.subplots()
    plt.title(f"pvalue for Irwin-Hall with n = {n}")
    for m in M:
        print(f"Irwin-Hall({m})")
        Y = np.sum(np.random.uniform(size=(m, n)), axis=0)
        task(Y, n)
        pval_ih(n,m)
    ax.legend()
    print("")
# Out:
# N(0,1)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.8833971040697818
# Hypothesis acceptance for n = 100: True. Pvalue: 0.8092140856681573
# Hypothesis acceptance for n = 500: True. Pvalue: 0.9334928931484671
#
# Bin(1, 1/2)
# Hypothesis acceptance for n = 50: False. Pvalue: 2.2401251370040492e-06
# Bin(2, 1/2)
# Hypothesis acceptance for n = 50: False. Pvalue: 0.006639193133245458
# Bin(5, 1/2)
# Hypothesis acceptance for n = 50: False. Pvalue: 0.003945314605707906
# Bin(20, 1/2)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.31939835797838767
#
# Bin(1, 1/2)
# Hypothesis acceptance for n = 100: False. Pvalue: 6.645269104308234e-11
# Bin(2, 1/2)
# Hypothesis acceptance for n = 100: False. Pvalue: 1.766204503979558e-05
# Bin(5, 1/2)
# Hypothesis acceptance for n = 100: False. Pvalue: 0.0018176429535392558
# Bin(20, 1/2)
# Hypothesis acceptance for n = 100: True. Pvalue: 0.13985565755411133
#
# Bin(1, 1/2)
# Hypothesis acceptance for n = 500: False. Pvalue: 3.627616204154637e-58
# Bin(2, 1/2)
# Hypothesis acceptance for n = 500: False. Pvalue: 6.034637416793425e-30
# Bin(5, 1/2)
# Hypothesis acceptance for n = 500: False. Pvalue: 1.4972973782027192e-15
# Bin(20, 1/2)
# Hypothesis acceptance for n = 500: False. Pvalue: 5.966618503975475e-05
#
# Irwin-Hall(1)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.515078856233804
# Irwin-Hall(2)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.983388360005486
# Irwin-Hall(5)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.7613452539416874
# Irwin-Hall(20)
# Hypothesis acceptance for n = 50: True. Pvalue: 0.43333335245424165
#
# Irwin-Hall(1)
# Hypothesis acceptance for n = 100: True. Pvalue: 0.5762026850814205
# Irwin-Hall(2)
# Hypothesis acceptance for n = 100: True. Pvalue: 0.9571558492590145
# Irwin-Hall(5)
# Hypothesis acceptance for n = 100: True. Pvalue: 0.8873275491835865
# Irwin-Hall(20)
# Hypothesis acceptance for n = 100: True. Pvalue: 0.47558200503598047
#
# Irwin-Hall(1)
# Hypothesis acceptance for n = 500: False. Pvalue: 0.017076582756946047
# Irwin-Hall(2)
# Hypothesis acceptance for n = 500: True. Pvalue: 0.5130395839115534
# Irwin-Hall(5)
# Hypothesis acceptance for n = 500: True. Pvalue: 0.7618547452679343
# Irwin-Hall(20)
# Hypothesis acceptance for n = 500: True. Pvalue: 0.32158330398190427

# %% [markdown]
# ![333.png](data:image/png;base64,...)

# %% [markdown]
# # 3)

# %%
N = [50, 100, 500]
def pval(n:int):
    m = 200
    result = []
    for j in range (m):
        Y = scst.norm.rvs(loc = 10, scale = 20, size = n)
        Sample = (Y - np.mean(Y))/np.std(Y)
        sample_val = sts.kstest(Sample, 'norm')
        result = np.append(result,sample_val.pvalue)
    result = np.sort(result)
    y_vals = [(i+1)/m for i in range(m)]
    ax.plot(result, y_vals, lw = 2)

for n in N:
    fig, ax = plt.subplots()
    plt.title(f"pvalue with n = {n}")
    Y = sts.norm.rvs(loc = 10, scale = 20, size = n)
    Sample = (Y - np.mean(Y))/np.std(Y)
    sample_val = sts.kstest(Sample, 'norm')
    print(f"Hypothesis test: {sample_val.pvalue > 0.05}")
    pval(n)
    print("")
# Out:
# Hypothesis test: True
#
# Hypothesis test: True
#
# Hypothesis test: True
